# %% [markdown]
# # This Notebook is intend to Plot the Wire configuration

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import import_ipynb
#from BelleII_data_managment import BelleII_get_data_path
#%matplotlib notebook

# %%
def BelleII_plot_cross_section(
    figsize = (14,14)                          # Figure size
    layers = [0,1,2,3,4,5,6,7,8]               # Plotted Layers    
):
    for layer in layers:

# %% [markdown]
# # Cross Section Plot

# %%
Super_layer_color = {0:"#ff0000",1:"#ffa500",2:"#ffff00",3:"#008000",4:"#0000ff",5:"#800080",6:"#da70d6",7:"#ff69b4",8:"#a52a2a"}
Super_Layer_marker = {0:"+",1:"o",2:"+",3:"o",4:"+",5:"o",6:"+",7:"o",8:"+"}

plt.figure(figsize=(24,24))
data_frame = pd.read_csv("tsf_coordinates_translation.txt")
for i in range(9):
    temp = data_frame[(data_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    #print(temp)
    #plt.plot(temp[:,0],temp[:,1],Super_Layer_marker[i])
    plt.plot(temp[:,0],temp[:,1],Super_Layer_marker[i])
    print(temp[:,0].shape)
    #plt.plot(temp[:,0],temp[:,1],"+")
    del temp
plt.grid()
plt.show()
# Out:
# (1280,)
# (960,)
# (1152,)
# (1344,)
# (1536,)
# (1728,)
# (1920,)
# (2112,)
# (2304,)

# %% [markdown]
# # 3D-Plot (Z-Axis : Super Layer)

# %%
Super_layer_color = {0:"red",1:"orange",2:"black",3:"green",4:"blue",5:"red",6:"orange",7:"black",8:"green"}
Super_Layer_marker = {0:".",1:"o",2:"+",3:"v",4:"d",5:"s",6:"o",7:"<",8:">"}


#%matplotlib notebook
plt.figure(figsize=(20,20))
ax = plt.axes(projection = "3d")

data_frame = pd.read_csv("tsf_coordinates_translation.txt")
for i in range(9):
    temp = data_frame[(data_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    #plt.plot(temp[:,0],temp[:,1],Super_Layer_marker[i])
    #plt.plot(temp[:,0],temp[:,1],i*50,Super_Layer_marker[i],color=Super_layer_color[i])
    ax.scatter(temp[:,0],temp[:,1],i,s=0.8,alpha = 1)
    del temp
plt.grid()
plt.show()

# %% [markdown]
# # 2D- Cross Section Event Plot

# %% [markdown]
# ### set Event_ID and datapath

# %%
#Event_ID = 14455
Event_ID = np.random.randint(0,14999)

figsize=(5,5)
On_linux = False

print(f"Event ID: {Event_ID}")

## Get datapath and vertexpath
if On_linux:
    data_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_tracks.txt"
else:
    data_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_tracks.txt"
# Out:
# Event ID: 10842

# %%
data_frame = pd.read_csv(data_path)
data_frame_label = pd.read_csv(vertex_path)

data_frame = data_frame[(data_frame["event"] == Event_ID)]
data_frame_label = data_frame_label[(data_frame_label["event"] ==Event_ID )]

data_np = data_frame.to_numpy()
data_np = data_np[:,4:6]
data_np = data_np * 10
print(data_np)
data_label_np = data_frame_label.to_numpy()
data_label_np = data_label_np * 10

#######
plt.figure(figsize=figsize)
### Plot Input
plt.plot(data_np[:,0],data_np[:,1],"o",color = "red",markersize = 2)
### Plot Background
data_frame = pd.read_csv("tsf_coordinates_translation.txt")
for i in range(9):
    temp = data_frame[(data_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    plt.plot(temp[:,0],temp[:,1],"+",markersize = 2,alpha = 0.5)
    del temp
### Plot Label
plt.plot(data_label_np[0][1],data_label_np[0][2],"X",color = "blue",markersize = 10)
plt.show()
# Out:
# [[-192.5 890.0]
#  [-188.0 909.0]
#  [-204.20000000000002 905.5]
#  [-199.89999999999998 925.0]
#  [-216.29999999999998 921.3]
#  [-195.2 944.5999999999999]
#  [-212.0 940.9000000000001]
#  [-190.10000000000002 964.0999999999999]
#  [-224.4 956.7]
#  [-202.2 979.7]
#  [-219.60000000000002 975.9000000000001]
#  [-237.0 971.8000000000001]
#  [-166.29999999999998 1007.3000000000001]
#  [-215.6 997.9000000000001]
#  [-160.79999999999998 1026.1]
#  [-227.60000000000002 1013.4000000000001]
#  [-172.2 1042.7]
#  [-223.1 1033.0]
#  [-166.5 1062.0]
#  [-235.6 1048.9]
#  [-160.39999999999998 1081.4]
#  [-248.29999999999998 1064.6]
#  [-172.10000000000002 1098.0]
#  [-243.5 1084.4]]

# %% [markdown]
# # 3D Event & Polar Plane Plot

# %% [markdown]
# ### set Event_ID and datapath

# %%
#Event_ID = 20
figsize=(15,15)
Event_ID = np.random.randint(0,14999)
On_linux = False

print(f"Event ID: {Event_ID}")

## Get datapath and vertexpath
if On_linux:
    data_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_tracks.txt"
else:
    data_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_tracks.txt"
# Out:
# Event ID: 8929

# %%
# %matplotlib notebook

data_frame = pd.read_csv(data_path)
data_frame_label = pd.read_csv(vertex_path)

print(f"<<<<<<<<<<<<<<<<<<<<<<<<<<<<EVENT_ID:{Event_ID}>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
print(f"the whole data_frame looks like:\n {data_frame}\n\n")

data_frame = data_frame[(data_frame["event"] == Event_ID)]
data_frame_label = data_frame_label[(data_frame_label["event"] ==Event_ID )]


print(f"<<<<<<<<<<<<<<<<<<<<<<<<<EVENT_ID:{Event_ID} Label>>>>>>>>>>>>>>>>>>>>>>>>>>")
print(f"Label for Event:{Event_ID} is \n: {data_frame_label}")

data_np = data_frame.to_numpy()
data_np = data_np[:,4:6]

data_label_np = data_frame_label.to_numpy()
data_label_np = data_label_np * 10


fig = plt.figure(figsize=figsize)
#ax = plt.axes(projection = "3d")
ax = fig.add_subplot(projection = "3d")

# plot background
data_frame = pd.read_csv("tsf_coordinates_translation.txt")
for i in range(9):
    temp = data_frame[(data_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    ax.scatter(temp[:,0],temp[:,1],-0.2,s=0.1,alpha = 0.2,marker = "x")
    r = np.sqrt(temp[:,0] ** 2+ temp[:,1] **2)
    phi = np.arctan2(temp[:,1],temp[:,0]) * 180 / np.pi
    phi_factor = 8
    r_factor = 2   
    ax.scatter(temp[:,0],temp[:,1],-i*0.00 -0. ,s=0.1,alpha = 0.5,marker = "o",color = "grey")
    del temp

    
##### PLOT THE INPUT
ax.scatter(data_np[:,0]*10,data_np[:,1]*10,0,s=1,alpha = 1,marker = "X",color = "red")


data_np = data_np.astype("float64")
ax.plot([data_label_np[0][1],data_label_np[0][1]],[data_label_np[0][2],data_label_np[0][2]],[-0.05,0.05],color = "green")
ax.plot([0,data_label_np[0][1]],[0,data_label_np[0][2]],[0,0],color = "blue")

ax.plot([0,0],[0,0],[-0.6,0.6],color = "grey")
ax.plot([0,0],[-1500,1500],[0,0],color = "grey")
ax.plot([-1500,1500],[0,0],[0,0],color = "black")

plt.show()
# Out:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<EVENT_ID:8929>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# the whole data_frame looks like:
#          Unnamed: 0  event  iCLayer ID  iWire ID       x      y sl_type  type
# 0                0      1           0        61  -12.56  11.14   axial  muon
# 1                1      1           0        74  -16.41   3.58   axial  muon
# 2                2      1           0        75  -16.54   2.93   axial  muon
# 3                3      1           0        76  -16.64   2.28   axial  muon
# 4                4      1           1        61  -13.07  12.06   axial  muon
# ...            ...    ...         ...       ...     ...    ...     ...   ...
# 902081      902081  14999          55       198 -110.51 -11.80   axial  muon
# 902082      902082  14999          55       199 -110.30 -13.61   axial  muon
# 902083      902083  14999          55       200 -110.07 -15.41   axial  muon
# 902084      902084  14999          55       201 -109.80 -17.21   axial  muon
# ...

# %% [markdown]
# # Polar Plane & Hits Map generator

# %%
#Event_ID = 20
figsize1=(30,15)
figsize2=(15,15)
Event_ID = np.random.randint(0,14999)
On_linux = False

print(f"Event ID: {Event_ID}")

## Get datapath and vertexpath
if On_linux:
    data_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "/home/updyh/DataSet/dark_Matter_Dataset_with_label/onshell_m2.0_bkgx0_tracks.txt"
else:
    data_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_AllHits.txt"
    vertex_path = "D:\KIT\Ma_Arbeit\Mark_Matter_dataset\dark_Matter_Dataset_with_label\onshell_m2.0_bkgx0_tracks.txt"
# Out:
# Event ID: 7800

# %%
data_frame_input = pd.read_csv(data_path)
data_frame_label = pd.read_csv(vertex_path)

## Extract the dataframe based 
data_frame_input = data_frame_input[(data_frame_input["event"] == Event_ID)]
data_frame_label = data_frame_label[(data_frame_label["event"] == Event_ID)]

#print(f"Event{Event_ID }\n data_frame_input is\n:{data_frame_input}")
#print(f"Event{Event_ID }\n data_frame_label is\n:{data_frame_label}")

data_frame_input = data_frame_input[["x","y"]]
#data_frame_input = data_frame_input[["iCLayer","iWire ID"]]
data_frame_label = data_frame_label[["vertex x","vertex y"]]

data_frame_input = data_frame_input.to_numpy(dtype = "float64")
data_frame_label = data_frame_label.to_numpy(dtype = "float64")

#####################################################################################
###################################################### Plot Original data 
#####################################################################################

##################################################### INPUT PLOT
#print(f"data_frame_input:\n{data_frame_input}")
#print(f"data_frame_label:\n{data_frame_label}")

data_frame_r = (data_frame_input[:,0] ** 2 + data_frame_input[:,1] ** 2) ** 0.5
#data_frame_phi = np.arctan2(data_frame_input[:,1],data_frame_input[:,0]) ## in rads
data_frame_phi = np.arctan2(data_frame_input[:,1],data_frame_input[:,0]) * 180 / np.pi ## in grad

data_frame_r = data_frame_r[:,np.newaxis]
data_frame_phi = data_frame_phi[:,np.newaxis]

plt.figure(figsize=figsize1)
plt.scatter(data_frame_phi,data_frame_r* 10,marker="x",color = "red",s = 100)

####################################################  LBAEL PLOT
print(f"the label is {data_frame_label}")
data_frame_label_r = (data_frame_label[:,0] ** 2 + data_frame_label[:,1] ** 2) ** 0.5
#data_frame_label_phi = np.arctan2(data_frame_label[:,1],data_frame_label[:,0]) ## in rads
data_frame_label_phi = np.arctan2(data_frame_label[:,1],data_frame_label[:,0]) * 180 / np.pi ## in grad
data_frame_label_r = data_frame_label_r[:,np.newaxis]
data_frame_label_phi = data_frame_label_phi[:,np.newaxis]
plt.scatter(data_frame_label_phi,data_frame_label_r*10,marker="X",s = 1000,color = "blue")

####################################################  WIRE PLOT
wire_frame = pd.read_csv("tsf_coordinates_translation.txt")
for i in range(9):
    temp = wire_frame[(wire_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    temp_r = (temp[:,0] ** 2 + temp[:,1] ** 2) **0.5
    temp_r = temp_r[:,np.newaxis]
    #temp_phi = np.arctan2(temp[:,1],temp[:,0])   # in rads
    temp_phi = np.arctan2(temp[:,1],temp[:,0]) * 180/ np.pi  # in grad
    temp_phi = temp_phi[:,np.newaxis]
    #plt.plot(temp[:,0],temp[:,1],Super_Layer_marker[i])
    #plt.plot(temp[:,0],temp[:,1],Super_Layer_marker[i])
    #plt.plot(temp[:,0],temp[:,1],"+")
    plt.scatter(temp_phi,temp_r,marker = "o",s = 0.5,alpha = 1)
    del temp
plt.grid()
plt.show()
#####################################################################################
###################################################### Plot Original data 
#####################################################################################
##### PLOT ring configuration
plt.figure(figsize=figsize2)
for i in range(9):
    temp = wire_frame[(wire_frame["superlayer id"] == i)]
    temp = temp.to_numpy(dtype="float64")
    temp = temp[:,-2:]
    plt.plot(temp[:,0],temp[:,1],"+",markersize = 2,alpha = 0.5)
    del temp
###### PLOT hits
plt.plot(data_frame_input[:,0]*10,data_frame_input[:,1]*10,"x",color="red")
###### PLOT vertex
plt.plot(data_frame_label[:,0]*10,data_frame_label[:,1]*10,"X",color="blue",markersize = 20)
plt.show()
# Out:
# the label is [[2.12 0.56]]
